# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
data=pd.read_csv(r"C:\Users\HP\Desktop\python\project 3\youtube_dislike_dataset.csv")

# %%
data.head(5)
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
data.tail(5)
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %%
data.shape
# Out:
# (37422, 12)

# %%
# we observed that there are 37422 rows and 12 columns, 8 columns are of object datatype  and rest are of int type

# %%
null=data.isnull().sum().sum()

# %%
null
# Out:
# 158

# %%
total=data.count().sum()

# %%
total
# Out:
# 448906

# %%
# percentage of missing values overall
(null/total)*100
# Out:
# 0.03519667814642709

# %%
missing_values = data.isna()  

# Step 4: Calculate the percentage of missing values in each column
missing_percentage = (missing_values.mean() * 100).round(2)

# %%
missing_percentage
# Out:
# video_id         0.00
# title            0.00
# channel_id       0.00
# channel_title    0.00
# published_at     0.00
# view_count       0.00
# likes            0.00
# dislikes         0.00
# comment_count    0.00
# tags             0.00
# description      0.00
# comments         0.42
# dtype: float64

# %%
data.dropna(inplace=True) # droped the missing values

# %%
data['video_id'].value_counts()
# Out:
# --0bCF-iK2E    1
# eW-61oOanMw    1
# eYdwd9dLAxQ    1
# eYhUTanUHaM    1
# eYwnU1DuJOo    1
#               ..
# K8qeRtOPDqs    1
# K8xAit6W3Rs    1
# K95MIzDth_A    1
# K96S2qroRN4    1
# zzxPZwaA-8w    1
# Name: video_id, Length: 37264, dtype: int64

# %%
data.describe() # for numerical columns
# Out:
#          view_count         likes      dislikes  comment_count
# count  3.726400e+04  3.726400e+04  3.726400e+04   3.726400e+04
# mean   5.710821e+06  1.672867e+05  4.996434e+03   9.966953e+03
# std    2.431304e+07  5.384931e+05  3.075194e+04   1.173465e+05
# min    2.036800e+04  2.200000e+01  3.000000e+00   1.000000e+00
# 25%    5.141305e+05  1.331725e+04  2.827500e+02   9.140000e+02
# 50%    1.321860e+06  4.255600e+04  7.980000e+02   2.347000e+03
# 75%    3.674527e+06  1.309665e+05  2.466250e+03   6.212000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07

# %%
label_encoder = LabelEncoder() # for catagorical columns

# %%
data.head(1)
# Out:
#       video_id                                 title  \
# 0  --0bCF-iK2E  Jadon Sancho  Magical Skills & Goals
#
#                  channel_id channel_title         published_at  view_count  \
# 0  UC6UL29enLNe4mqwTfAyeNuw    Bundesliga  2021-07-01 10:00:00     1048888
#
#    likes  dislikes  comment_count  \
# 0  19515       226           1319
#
#                                                 tags  \
# 0  football soccer ftbol alemn Bundesliga season ...
#
#                                          description  \
# 0  Enjoy the best skills and goals from Jadon San...
#
#                                             comments
# 0  Respect to Dortmund fans,must be sad losing hi...

# %%
catagorical_data= data[['video_id','title','channel_id','channel_title','tags','description','comments']]

# %%
catagorical_data
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title  \
# 0      UC6UL29enLNe4mqwTfAyeNuw             Bundesliga
# ...

# %%
data['video_id'] = label_encoder.fit_transform(data['video_id'])

# %%
data['video_id'].value_counts()
# Out:
# 0        1
# 24819    1
# 24839    1
# 24840    1
# 24841    1
#         ..
# 12421    1
# 12422    1
# 12423    1
# 12424    1
# 37263    1
# Name: video_id, Length: 37264, dtype: int64

# %%
data['video_id'].unique()
# Out:
# array([    0,     1,     2, ..., 37261, 37262, 37263])

# %%
data
# Out:
#        video_id                                              title  \
# 0             0               Jadon Sancho  Magical Skills & Goals
# 1             1                 Migos - Avalanche (Official Video)
# 2             2         Supporting Actress in a Comedy: 73rd Emmys
# 3             3            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4             4                       Why Retaining Walls Collapse
# ...         ...                                                ...
# 37417     37259  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418     37260  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419     37261                 [MV]  (MAMAMOO) - Where Are We Now
# 37420     37262              FELLIPE ESCUDERO- Master Podcast  #12
# 37421     37263  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# 0      UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# ...

# %%
data[''] = label_encoder.fit_transform(data['video_id'])

# %%
for col in data[['video_id','title','channel_id','channel_title','tags','description','comments']]:
    data[col]=label_encoder.fit_transform(data[col])

# %%
data
# Out:
#        video_id  title  channel_id  channel_title         published_at  \
# 0             0  17079        1339           1505  2021-07-01 10:00:00
# 1             1  21423        3029           6007  2021-06-10 16:00:00
# 2             2  29128        8376           8836  2021-09-20 01:03:32
# 3             3  16947        9717           4243  2021-03-03 10:00:17
# 4             4  34747        4048           7156  2021-12-07 13:00:00
# ...         ...    ...         ...            ...                  ...
# 37417     37259  19639        2622           5313  2021-02-12 05:03:49
# 37418     37260  24296        5732           6310  2021-01-16 05:39:05
# 37419     37261  35834       10062           5536  2021-06-02 09:00:10
# 37420     37262  10780        1667           5854  2020-10-20 20:59:30
# 37421     37263  12383        2712           9338  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count   tags  description  \
# ...

# %%
data[['video_id','title','channel_id','channel_title','tags','description','comments']].describe() # catagorical anlysis
# Out:
#            video_id         title    channel_id  channel_title          tags  \
# count  37264.000000  37264.000000  37264.000000   37264.000000  37264.000000
# mean   18631.500000  18513.532256   5405.049512    5523.273991  12788.672875
# std    10757.334552  10694.009854   3140.221344    3119.435856   8972.144844
# min        0.000000      0.000000      0.000000       0.000000      0.000000
# 25%     9315.750000   9246.750000   2670.000000    2748.000000   4644.750000
# 50%    18631.500000  18524.500000   5334.000000    5706.000000  12548.500000
# 75%    27947.250000  27790.250000   8142.000000    8226.000000  20598.250000
# max    37263.000000  36957.000000  10890.000000   10812.000000  28704.000000
#
#         description      comments
# count  37264.000000  37264.000000
# mean   17384.823073  18631.500000
# std    10395.764410  10757.334552
# min        0.000000      0.000000
# 25%     8335.750000   9315.750000
# 50%    17360.500000  18631.500000
# ...

# %%
data['published_at']=pd.to_datetime(data['published_at'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37264 entries, 0 to 37421
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37264 non-null  int64
#  1   title          37264 non-null  int32
#  2   channel_id     37264 non-null  int32
#  3   channel_title  37264 non-null  int32
#  4   published_at   37264 non-null  datetime64[ns]
#  5   view_count     37264 non-null  int64
#  6   likes          37264 non-null  int64
#  7   dislikes       37264 non-null  int64
#  8   comment_count  37264 non-null  int64
#  9   tags           37264 non-null  int32
#  10  description    37264 non-null  int32
#  11  comments       37264 non-null  int32
#  12                 37264 non-null  int64
# dtypes: datetime64[ns](1), int32(6), int64(6)
# memory usage: 3.1 MB

# %%
# changed to data time

# %%
data['published_month']=data['published_at'].dt.month    # fetching only month from date

# %%
data['published_month']
# Out:
# 0         7
# 1         6
# 2         9
# 3         3
# 4        12
#          ..
# 37417     2
# 37418     1
# 37419     6
# 37420    10
# 37421     5
# Name: published_month, Length: 37264, dtype: int64

# %%
month={1:"jan",2:"feb",3:"mar",4:"apr",5:"may",6:"jun",7:"july",8:"aug",9:"sep",10:"oct",11:"nov",12:"dec"}

# %%
data['published_month']=data['published_month'].replace(month)

# %%
data['published_month']
# Out:
# 0        july
# 1         jun
# 2         sep
# 3         mar
# 4         dec
#          ...
# 37417     feb
# 37418     jan
# 37419     jun
# 37420     oct
# 37421     may
# Name: published_month, Length: 37264, dtype: object

# %%
data
# Out:
#        video_id  title  channel_id  channel_title        published_at  \
# 0             0  17079        1339           1505 2021-07-01 10:00:00
# 1             1  21423        3029           6007 2021-06-10 16:00:00
# 2             2  29128        8376           8836 2021-09-20 01:03:32
# 3             3  16947        9717           4243 2021-03-03 10:00:17
# 4             4  34747        4048           7156 2021-12-07 13:00:00
# ...         ...    ...         ...            ...                 ...
# 37417     37259  19639        2622           5313 2021-02-12 05:03:49
# 37418     37260  24296        5732           6310 2021-01-16 05:39:05
# 37419     37261  35834       10062           5536 2021-06-02 09:00:10
# 37420     37262  10780        1667           5854 2020-10-20 20:59:30
# 37421     37263  12383        2712           9338 2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count   tags  description  \
# ...

# %%
number_of_videos = data.pivot_table(index='published_month', aggfunc='size').reset_index(name='video_count')

# %%
number_of_videos    # number of videos count in each month
# Out:
#    published_month  video_count
# 0              apr         2119
# 1              aug         4250
# 2              dec         3063
# 3              feb         2125
# 4              jan         2099
# 5             july         2331
# 6              jun         2305
# 7              mar         2248
# 8              may         2073
# 9              nov         4821
# 10             oct         4976
# 11             sep         4854

# %%
unique=data[['video_id', 'channel_id', 'channel_title']].nunique()

# %%
unique                                           # count of unique data
# Out:
# video_id         37264
# channel_id       10891
# channel_title    10813
# dtype: int64

# %%
# channel_counts = data['channel_title'].value_counts()

# %%
# channel_counts

# %%
pivot_table = data.pivot_table(index='channel_title', aggfunc='size').reset_index(name='video_count')

sorted_pivot_table = pivot_table.sort_values(by='video_count', ascending=False)

# %%
sorted_pivot_table.head(10)                  # top 10
# Out:
#       channel_title  video_count
# 8223           8223          533
# 9098           9098          301
# 1085           1085          246
# 6310           6310          209
# 6347           6347          162
# 9780           9780          122
# 7809           7809           99
# 7810           7810           98
# 3037           3037           87
# 6352           6352           86

# %%
sorted_pivot_table.tail(10)                   # bottom 10
# Out:
#        channel_title  video_count
# 4790            4790            1
# 4787            4787            1
# 4786            4786            1
# 4785            4785            1
# 4784            4784            1
# 4782            4782            1
# 4777            4777            1
# 4776            4776            1
# 4775            4775            1
# 10812          10812            1

# %%
data.groupby(['title','likes']).sum().sort_values(by='likes').head(1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_44448\1450782807.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['title','likes']).sum().sort_values(by='likes').head(1)
#              video_id  channel_id  channel_title  view_count  dislikes  \
# title likes
# 19316 22        23764        1566           1948     2254615         9
#
#              comment_count  tags  description  comments
# title likes
# 19316 22                12  3856         6123     28970  23764

# %%
# title 19316 has minimum number of likes

# %%
data.groupby(['title','likes']).sum().sort_values(by='likes',ascending=False).head(1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_44448\3749562185.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['title','likes']).sum().sort_values(by='likes',ascending=False).head(1)
#                 video_id  channel_id  channel_title  view_count  dislikes  \
# title likes
# 5233  31837675     26043         796           3777  1322796924   1814333
#
#                 comment_count  tags  description  comments
# title likes
# 5233  31837675       16071029  2702         6501      5565  26043

# %%
# title 5233 has maximum number of likes

# %%
data.groupby(['title','dislikes']).sum().sort_values(by='likes').head(1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_44448\542277159.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['title','dislikes']).sum().sort_values(by='likes').head(1)
#                 video_id  channel_id  channel_title  view_count  likes  \
# title dislikes
# 19316 9            23764        1566           1948     2254615     22
#
#                 comment_count  tags  description  comments
# title dislikes
# 19316 9                    12  3856         6123     28970  23764

# %%
# title 19316 has minimum number of dislikes

# %%
data.groupby(['title','dislikes']).sum().sort_values(by='likes',ascending=False).head(1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_44448\2076214387.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['title','dislikes']).sum().sort_values(by='likes',ascending=False).head(1)
#                 video_id  channel_id  channel_title  view_count     likes  \
# title dislikes
# 5233  1814333      26043         796           3777  1322796924  31837675
#
#                 comment_count  tags  description  comments
# title dislikes
# 5233  1814333        16071029  2702         6501      5565  26043

# %%
# title 5233 has maximum number of dislikes

# %%
plt.scatter(data['likes'], data['dislikes'])

# %%
correlation_coefficient = data['likes'].corr(data['dislikes'])

# %%
correlation_coefficient
# Out:
# 0.6796676237152303

# %%
# yes there is strong relation between likes and dislikes of people 
# from above scatter plot we can conclude that there is positive relation between likes and dislikes of people
# as likes are increasing so as dislikes are also incresing

# %%
data[data['published_month']=='jan'].shape[0]
# Out:
# 2099

# %%
# count of videos that were published in january

# %%
data[data['published_month']=='jan']             # information from jan month
# Out:
#        video_id  title  channel_id  channel_title        published_at  \
# 27           27  25370        6153           5982 2021-01-21 00:05:47
# 48           48  27472        4633            616 2021-01-16 21:40:04
# 95           95  33371        5655           8857 2021-01-03 21:53:48
# 103         103   9301       10866           3630 2021-01-19 11:00:01
# 182         182  27752        5772           1284 2021-01-24 22:50:57
# ...         ...    ...         ...            ...                 ...
# 37300     37142   8438        3431           7072 2021-01-16 16:12:19
# 37329     37171  19147        8220           8996 2021-01-03 20:13:49
# 37345     37187  19658        4350           5314 2021-01-21 05:00:10
# 37383     37225  24449        8847            712 2021-01-15 04:07:55
# 37418     37260  24296        5732           6310 2021-01-16 05:39:05
#
#        view_count   likes  dislikes  comment_count   tags  description  \
# ...
